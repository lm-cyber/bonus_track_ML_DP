# %%
# !pip install catboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 12.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive # блок для google colab
drive.mount('/content/gdrive/', force_remount=True)
import numpy as np 
import pandas as pd
import six
import catboost as cb
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_csv('gdrive/MyDrive/titanic_train.csv') # датасет
df_cheak = pd.read_csv('gdrive/MyDrive/titanic_reserved.csv') # датасет

# %%
from catboost import CatBoostClassifier

# %%
model = CatBoostClassifier(iterations=1000,
                           task_type="CPU")
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       3         1                               Smyth, Miss. Julia  female
# 1       3         1                         Glynn, Miss. Mary Agatha  female
# 2       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)  female
# 3       3         0                                  Vovk, Mr. Janko    male
# 4       3         0                        de Pelsmaeker, Mr. Alfons    male
#
#     age  sibsp  parch  ticket    fare cabin embarked  \
# 0   NaN      0      0  335432  7.7333   NaN        Q
# 1   NaN      0      0  335677  7.7500   NaN        Q
# 2  38.0      0      0    2688  7.2292   NaN        C
# 3  22.0      0      0  349252  7.8958   NaN        S
# 4  16.0      0      0  345778  9.5000   NaN        S
#
#                           home.dest
# 0                               NaN
# 1  Co Clare, Ireland Washington, DC
# 2                               NaN
# ...

# %%
x = df.drop(['survived','name'],axis=1)
y = df['survived']
xt = df_cheak.drop(['name'],axis=1)

# %%
model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# _catboost.pyx in _catboost.get_float_feature()
#
# _catboost.pyx in _catboost._FloatOrNan()
#
# _catboost.pyx in _catboost._FloatOrNanFromString()
#
# TypeError: Cannot convert 'b'female'' to float
#
# During handling of the above exception, another exception occurred:
#
# CatBoostError                             Traceback (most recent call last)
# <ipython-input-23-cecb4634e72d> in <cell line: 1>()
# ----> 1 model.fit(x,y)
#
# /usr/local/lib/python3.9/dist-packages/catboost/core.py in fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
# ...
