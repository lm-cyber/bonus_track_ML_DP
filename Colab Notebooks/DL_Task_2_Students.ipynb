# %% [markdown]
# ## Импортируем нужные библиотеки

# %%
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ## Загружаем датасет

# %%
# !gdown 1o42zw-uR_uCLPWhcFGbrUz56UkC6HgvQ
df = pd.read_csv('360T.csv')
df
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1o42zw-uR_uCLPWhcFGbrUz56UkC6HgvQ
# To: /content/360T.csv
# 100% 490k/490k [00:00<00:00, 46.9MB/s]
#       num_frames  num_frames_avg  num_packets  num_packets_avg  \
# 0          38007            2533        31348             2089
# 1          32695            2179        26253             1750
# 2          32655            2177        26396             1759
# 3          33541            2236        26612             1774
# 4          32925            2195        26472             1764
# ...          ...             ...          ...              ...
# 2331       33025            2201        26446             1763
# 2332       33072            2204        26372             1758
# 2333       32555            2170        26043             1736
# 2334       33033            2202        26395             1759
# 2335       33079            2205        26341             1756
#
#       num_packets_out_avg  num_packets_out_max  num_packets_out_min  \
# 0                     218                 1777                   46
# 1                     212                 1726                   48
# 2                     212                 1654                   41
# 3                     213                 1695                   50
# 4                     213                 1750                   44
# ...                   ...                  ...                  ...
# 2331                  212                 1654                   45
# 2332                  211                 1685                   39
# 2333                  210                 1667                   48
# 2334                  212                 1714                   47
# 2335                  213                 1686                   50
#
#       num_packets_in_avg  num_packets_in_max  num_packets_in_min  ...  \
# 0                    266                2266                  38  ...
# 1                    212                1814                  34  ...
# 2                    212                1701                  30  ...
# 3                    214                1741                  38  ...
# 4                    213                1805                  35  ...
# ...                  ...                 ...                 ...  ...
# 2331                 213                1674                  37  ...
# 2332                 212                1721                  39  ...
# 2333                 210                1716                  37  ...
# 2334                 213                1722                  38  ...
# 2335                 212                1734                  38  ...
#
#       num_forwarded_packets_avg  num_forwarded_packets_max  \
# 0                           583                       1328
# 1                           575                       1344
# 2                           578                       1270
# 3                           586                       1316
# 4                           586                       1375
# ...                         ...                        ...
# 2331                        579                       1273
# 2332                        573                       1307
# 2333                        567                       1289
# 2334                        581                       1335
# 2335                        578                       1307
#
#       num_forwarded_packets_min  num_packets_created_avg  \
# 0                           108                       69
# 1                           105                       32
# 2                           120                       21
# 3                           112                        1
# 4                           115                        1
# ...                         ...                      ...
# 2331                        126                        1
# 2332                        106                        1
# 2333                        117                        1
# 2334                         92                        1
# 2335                        118                        1
#
#       num_packets_created_max  num_packets_created_min  \
# 0                         136                       46
# 1                          83                       48
# 2                          76                       41
# 3                          82                       50
# 4                          83                       44
# ...                       ...                      ...
# 2331                       81                       45
# 2332                       86                       39
# 2333                       77                       48
# 2334                       79                       46
# 2335                       82                       50
#
#       frac_packets_created_acquired_avg  frac_packets_created_acquired_max  \
# 0                                  1.02                                  2
# 1                                  1.00                                  1
# 2                                  1.00                                  1
# 3                                  1.00                                  1
# 4                                  1.00                                  1
# ...                                 ...                                ...
# 2331                               1.00                                  1
# 2332                               1.00                                  1
# 2333                               1.00                                  1
# 2334                               1.00                                  1
# 2335                               1.00                                  1
#
#       frac_packets_created_acquired_min  class
# 0                                     1      0
# 1                                     1      0
# 2                                     1      0
# 3                                     1      0
# 4                                     1      0
# ...                                 ...    ...
# 2331                                  1      1
# 2332                                  1      1
# 2333                                  1      1
# 2334                                  1      1
# 2335                                  1      1
#
# [2336 rows x 52 columns]

# %%
# !ls
# Out:
# 360T.csv  sample_data

# %% [markdown]
# Посмотрим на распределение откликов

# %%
plt.hist(df['class'],bins = 2)
# Out:
# (array([  85., 2251.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %% [markdown]
# Разделим датасет на обучающую и тестовую выборки. Из-за неоднородности объектов используем стратификацию по столбцу откликов.

# %%
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], 
                                                    test_size=0.3, random_state=65, stratify = df.iloc[:,-1])

# %% [markdown]
# Произведем стандартизацию признаков

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
# Обучаем скейлер на X_train и применяем преобразование
X_train_scaled = sc.fit_transform(X_train)

# Преобразовываем X_test
X_test_scaled = sc.transform(X_test)

# %% [markdown]
# ## Строим классификатор

# %%
mlp = MLPClassifier(random_state=65, 
                    hidden_layer_sizes=(31,10), # Используем три скрытых слоя и укажем число нейронов в каждом
                    activation='logistic', # Определим функцию активации
                    max_iter=1000, # Максимальное число эпох обучения
                   )
mlp.fit(X_train_scaled, y_train)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=(31, 10), max_iter=1000,
#               random_state=65)

# %% [markdown]
# Посмотрим, как убывал loss в зависимости от номера эпохи обучения

# %%
plt.plot(mlp.loss_curve_)

# %% [markdown]
# Произведем оценку нашей модели

# %%
y_mlp_pred = mlp.predict(X_test_scaled)
y_mlp_pred
print(classification_report(y_test, y_mlp_pred, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.636     0.538     0.583        26
#            1      0.982     0.988     0.985       675
#
#     accuracy                          0.971       701
#    macro avg      0.809     0.763     0.784       701
# weighted avg      0.969     0.971     0.970       701

# %% [markdown]
# ## Предсказание
#
# Выполним предсказание для первого объекта тестовой выборки

# %%
X_test.head()
# Out:
#       num_frames  num_frames_avg  num_packets  num_packets_avg  \
# 1974       33198            2213        26470             1764
# 221        31535            2102        25207             1680
# 1499       32789            2185        26408             1760
# 295        31703            2113        25493             1699
# 719        33720            2248        27162             1810
#
#       num_packets_out_avg  num_packets_out_max  num_packets_out_min  \
# 1974                  212                 1749                   45
# 221                   205                 1608                   20
# 1499                  222                 1702                   46
# 295                   220                 1568                   50
# 719                   217                 1798                   49
#
#       num_packets_in_avg  num_packets_in_max  num_packets_in_min  ...  \
# 1974                 213                1834                  39  ...
# 221                  204                1611                  34  ...
# 1499                 213                1784                  33  ...
# 295                  207                1574                  28  ...
# 719                  218                1850                  34  ...
#
#       num_forwarded_packets  num_forwarded_packets_avg  \
# 1974                   8710                        581
# 221                    8393                        560
# 1499                   8920                        595
# 295                    8593                        573
# 719                    9036                        602
#
#       num_forwarded_packets_max  num_forwarded_packets_min  \
# 1974                       1371                         83
# 221                        1227                        137
# 1499                       1328                        113
# 295                        1190                        104
# 719                        1419                         98
#
#       num_packets_created_avg  num_packets_created_max  \
# 1974                        1                       78
# 221                         0                       77
# 1499                        1                      190
# 295                         2                      382
# 719                         0                       84
#
#       num_packets_created_min  frac_packets_created_acquired_avg  \
# 1974                       45                               0.99
# 221                        20                               0.14
# 1499                       44                               0.99
# 295                        50                               1.00
# 719                        42                               1.00
#
#       frac_packets_created_acquired_max  frac_packets_created_acquired_min
# 1974                                  1                                  0
# 221                                   1                                  0
# 1499                                  1                                  0
# 295                                   1                                  1
# 719                                   1                                  1
#
# [5 rows x 51 columns]

# %%
# Выбираем произвольный объект из начального набора данных
test_obj = X_test.loc[[1974]]

# Не забываем масштабировать признаки тестового объекта 
test_obj = sc.transform(test_obj)
print("Assigned class: ",mlp.predict(test_obj))
# Out:
# Assigned class:  [1]

# %%
test_obj = pd.read_csv('https://courses.openedu.ru/assets/courseware/v1/ab75da6cdf6315f16705cd0e43f69aac/asset-v1:ITMOUniversity+bonus_track_3+spring_2023+type@asset+block/DL_Task_2_test_file_44.csv')

test_obj = sc.transform(test_obj)
print("Assigned class: ",mlp.predict(test_obj))
test_obj = pd.read_csv('https://courses.openedu.ru/assets/courseware/v1/ba0102632b05adaa70d5db089215d314/asset-v1:ITMOUniversity+bonus_track_3+spring_2023+type@asset+block/DL_Task_2_test_file_78.csv')

test_obj = sc.transform(test_obj)
print("Assigned class: ",mlp.predict(test_obj))
test_obj = pd.read_csv('https://courses.openedu.ru/assets/courseware/v1/92947739c0fb4c8303ff207d82664e82/asset-v1:ITMOUniversity+bonus_track_3+spring_2023+type@asset+block/DL_Task_2_test_file_107.csv')

test_obj = sc.transform(test_obj)
print("Assigned class: ",mlp.predict(test_obj))
test_obj = pd.read_csv('https://courses.openedu.ru/assets/courseware/v1/e3790f31e3db983570a8ab3319c94e50/asset-v1:ITMOUniversity+bonus_track_3+spring_2023+type@asset+block/DL_Task_2_test_file_166.csv')

test_obj = sc.transform(test_obj)
print("Assigned class: ",mlp.predict(test_obj))
# Out:
# Assigned class:  [0]
# Assigned class:  [0]
# Assigned class:  [1]
# Assigned class:  [1]
